# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
museum_filepath = "V:\Data & Analytics\Sandbox\Gage\Python\Museum_Visitors.csv"

# Fill in the line below to read the file into a variable museum_data
museum_data = pd.read_csv(museum_filepath, index_col="Month", parse_dates=True)

# %%
museum_data.head()
# Out:
#             America Tropical Interpretive Center  Avila Adobe  \
# Month
# 2014-01-01                                  6602        24778
# 2014-02-01                                  5029        18976
# 2014-03-01                                  8129        25231
# 2014-04-01                                  2824        26989
# 2014-05-01                                 10694        36883
#
#             Chinese American Museum  Gateway to Nature Center  \
# Month
# 2014-01-01                     1581                       NaN
# 2014-02-01                     1785                       NaN
# 2014-03-01                     3229                       NaN
# 2014-04-01                     2129                       NaN
# 2014-05-01                     3676                       NaN
#
#             Firehouse Museum  Hellman Quon  IAMLA  Pico House   \
# Month
# 2014-01-01              4486           0.0    NaN       2204.0
# 2014-02-01              4172           0.0    NaN       1330.0
# 2014-03-01              7082          70.0    NaN       4320.0
# 2014-04-01              6756         250.0    NaN       3277.0
# 2014-05-01             10858         135.0    NaN       4122.0
#
#             Visitor Center/ El Tranquilo Gallery  Museum of Social Justice  \
# Month
# 2014-01-01                                2961.0                       NaN
# 2014-02-01                                2276.0                       NaN
# 2014-03-01                                3116.0                       NaN
# 2014-04-01                                2808.0                       NaN
# 2014-05-01                                3987.0                       NaN
#
#             Biscailuz Gallery/ PK Outdoor Exhibit
# Month
# 2014-01-01                                    NaN
# 2014-02-01                                    NaN
# 2014-03-01                                    NaN
# 2014-04-01                                    NaN
# 2014-05-01                                    NaN

# %%
museum_data.tail()
# Out:
#             America Tropical Interpretive Center  Avila Adobe  \
# Month
# 2021-09-01                                  2225         5500
# 2021-10-01                                  2807         7201
# 2021-11-01                                  2192         6916
# 2021-12-01                                  1089         4128
# 2022-01-01                                   786         3756
#
#             Chinese American Museum  Gateway to Nature Center  \
# Month
# 2021-09-01                      193                       0.0
# 2021-10-01                      502                       0.0
# 2021-11-01                      676                       0.0
# 2021-12-01                      476                       0.0
# 2022-01-01                      455                       0.0
#
#             Firehouse Museum  Hellman Quon  IAMLA  Pico House   \
# Month
# 2021-09-01              1370           0.0  482.0          0.0
# 2021-10-01              1762           0.0  515.0          0.0
# 2021-11-01              1846           0.0  609.0          0.0
# 2021-12-01               967           0.0  380.0          0.0
# 2022-01-01               823           0.0  353.0          0.0
#
#             Visitor Center/ El Tranquilo Gallery  Museum of Social Justice  \
# Month
# 2021-09-01                                   0.0                     817.0
# 2021-10-01                                   0.0                    1347.0
# 2021-11-01                                   0.0                     756.0
# 2021-12-01                                   0.0                     301.0
# 2022-01-01                                   0.0                     277.0
#
#             Biscailuz Gallery/ PK Outdoor Exhibit
# Month
# 2021-09-01                                    0.0
# 2021-10-01                                    0.0
# 2021-11-01                                    0.0
# 2021-12-01                                    0.0
# 2022-01-01                                    0.0

# %%
plt.figure(figsize=(20,12))
sns.lineplot(data=museum_data)
plt.title("Monthly Visitors to los Angeles City Museums")
# Out:
# Text(0.5, 1.0, 'Monthly Visitors to los Angeles City Museums')

# %%
plt.figure(figsize=(20,12))
sns.lineplot(data=museum_data["Avila Adobe"])
plt.ylabel("Visitors")
plt.xlabel("Date")
plt.title("Monthly Visitors to Avila Adobe")
# Out:
# Text(0.5, 1.0, 'Monthly Visitors to Avila Adobe')
